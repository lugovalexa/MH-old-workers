# %%
import pandas as pd

# %%
yc456_3d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w456_year_country.csv"
)
yc456_3d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w456_year_country_common.csv"
)
y456_3d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w456_year.csv"
)
y456_3d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w456_year_common.csv"
)
yc46_3d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w46_year_country.csv"
)
yc46_3d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w46_year_country_common.csv"
)
y46_3d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w46_year.csv"
)
y46_3d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/3digits_w46_year_common.csv"
)

yc456_4d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w456_year_country.csv"
)
yc456_4d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w456_year_country_common.csv"
)
y456_4d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w456_year.csv"
)
y456_4d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w456_year_common.csv"
)
yc46_4d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w46_year_country.csv"
)
yc46_4d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w46_year_country_common.csv"
)
y46_4d = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w46_year.csv"
)
y46_4d_c = pd.read_csv(
    "/Users/alexandralugova/Documents/GitHub/MH-old-workers/data/datasets/results/4digits_w46_year_common.csv"
)

# %%
print("3 digits")
print("-------------------------------------")
print(f"Waves 4,5,6: {yc456_3d.mergeid.nunique()} if join by year and country")
print(f"Waves 4,5,6: {y456_3d.mergeid.nunique()} if join by year")
print("......")
print(f"Waves 4,5,6 common: {yc456_3d_c.mergeid.nunique()} if join by year and country")
print(f"Waves 4,5,6 common: {y456_3d_c.mergeid.nunique()} if join by year")
print("......")
print(f"Waves 4 and 6: {yc46_3d.mergeid.nunique()} if join by year and country")
print(f"Waves 4 and 6: {y46_3d.mergeid.nunique()} if join by year")
print("......")
print(
    f"Waves 4 and 6 common: {yc46_3d_c.mergeid.nunique()} if join by year and country"
)
print(f"Waves 4 and 6 common: {y46_3d_c.mergeid.nunique()} if join by year")
print("=================================================")
print("4 digits")
print("-------------------------------------")
print(f"Waves 4,5,6: {yc456_4d.mergeid.nunique()} if join by year and country")
print(f"Waves 4,5,6: {y456_4d.mergeid.nunique()} if join by year")
print("......")
print(f"Waves 4,5,6 common: {yc456_4d_c.mergeid.nunique()} if join by year and country")
print(f"Waves 4,5,6 common: {y456_4d_c.mergeid.nunique()} if join by year")
print("......")
print(f"Waves 4 and 6: {yc46_4d.mergeid.nunique()} if join by year and country")
print(f"Waves 4 and 6: {y46_4d.mergeid.nunique()} if join by year")
print("......")
print(
    f"Waves 4 and 6 common: {yc46_4d_c.mergeid.nunique()} if join by year and country"
)
print(f"Waves 4 and 6 common: {y46_4d_c.mergeid.nunique()} if join by year")
# Out:
# 3 digits
# -------------------------------------
# Waves 4,5,6: 5647 if join by year and country
# Waves 4,5,6: 6772 if join by year
# ......
# Waves 4,5,6 common: 994 if join by year and country
# Waves 4,5,6 common: 1703 if join by year
# ......
# Waves 4 and 6: 5121 if join by year and country
# Waves 4 and 6: 6007 if join by year
# ......
# Waves 4 and 6 common: 1292 if join by year and country
# Waves 4 and 6 common: 2005 if join by year
# ...
# 4 digits
# -------------------------------------
# Waves 4,5,6: 4421 if join by year and country
# Waves 4,5,6: 6585 if join by year
# ......
# Waves 4,5,6 common: 712 if join by year and country
# Waves 4,5,6 common: 1639 if join by year
# ......
# Waves 4 and 6: 4058 if join by year and country
# Waves 4 and 6: 5866 if join by year
# ......
# Waves 4 and 6 common: 844 if join by year and country
# Waves 4 and 6 common: 1920 if join by year
